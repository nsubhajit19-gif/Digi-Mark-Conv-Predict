# %% [markdown]
# # Data Cleaning
#
# ## Project: Digital Marketing Campaign Conversion Prediction
#
# - we perform initial data understanding and data cleaning.
# - The objective is to explore the raw dataset, identify data quality issues, and create a cleaned dataset.
# - that will be used for further preprocessing, EDA, and model development.

# %%
# %pip install matplotlib seaborn

# Data manipulation libraries
import pandas as pd
import numpy as np

# Visualization libraries (used later if required)
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load Dataset

# %%
# Loading data
Digi_Marketing = pd.read_csv(r'C:\Capstone Project DS Subhajit Nandy\Digital Marketing Campaign Conversion Prediction\data\digital_marketing_campaign_dataset.csv')
Digi_Marketing.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Loading data
# ----> 2 Digi_Marketing = pd.read_csv(r'C:\Capstone Project DS Subhajit Nandy\Digital Marketing Campaign Conversion Prediction\data\digital_marketing_campaign_datasetcsv')
#       3 Digi_Marketing.head()
#
# ...

# %% [markdown]
# # Data Backup

# %%
digital_marketing_campaign_cleaned = Digi_Marketing
digital_marketing_campaign_cleaned.head()

# %% [markdown]
# ## Dataset and Structure
#
# - Number of rows and columns
# - Data types of features
# - Presence of missing values

# %%
# Dataset structure
digital_marketing_campaign_cleaned.info()

# %%
## Check the number of missing values in each column. 
digital_marketing_campaign_cleaned.isnull().sum()

# %%
# Check the number of duplicate values in each column.
digital_marketing_campaign_cleaned.duplicated().sum()

# %% [markdown]
# ## Statistical Summary
#
# - Outliers
# - Unexpected minimum or maximum values
# - Data distribution patterns

# %%
# Summary
digital_marketing_campaign_cleaned.describe()

# %% [markdown]
# ## Target Variable Analysis
#
# Check the distribution of the target variable to confirm:
# - Classification type (Binary)
# - Class imbalance

# %%
# Target variable
digital_marketing_campaign_cleaned['Reached.on.Time_Y.N'].value_counts()

# %%
# Exporting cleaned data
digital_marketing_campaign_cleaned.to_csv(r'C:\Capstone Project DS Subhajit Nandy\Digital Marketing Campaign Conversion Prediction\data\digital_marketing_campaign_cleaned.csv', index=False)
